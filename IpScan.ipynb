# %%
import subprocess
import ipaddress
from subprocess import Popen, PIPE
network = ipaddress.ip_network('192.168.1.0/24')

for i in network.hosts():
    i=str(i)
    toping = Popen(['ping','-c','1', '-t', '1.0', i], stdout=PIPE)
    output=toping.communicate()[0]
    hostalive=toping.returncode
    if hostalive ==0:
         print (i,'is reachable')
    else:
        print(i,'is unreachable')
# Out:
# 192.168.1.1 is reachable
# 192.168.1.2 is reachable
# 192.168.1.3 is reachable
# 192.168.1.4 is reachable
# 192.168.1.5 is reachable
# 192.168.1.6 is reachable
# 192.168.1.7 is reachable
# 192.168.1.8 is reachable
# 192.168.1.9 is reachable
# 192.168.1.10 is reachable
# 192.168.1.11 is reachable
# 192.168.1.12 is unreachable
# 192.168.1.13 is unreachable
# 192.168.1.14 is reachable
# 192.168.1.15 is unreachable
# 192.168.1.16 is unreachable
# 192.168.1.17 is unreachable
# 192.168.1.18 is unreachable
# 192.168.1.19 is unreachable
# 192.168.1.20 is unreachable
# 192.168.1.21 is unreachable
# 192.168.1.22 is unreachable
# 192.168.1.23 is unreachable
# 192.168.1.24 is unreachable
# 192.168.1.25 is unreachable
# 192.168.1.26 is unreachable
# 192.168.1.27 is unreachable
# 192.168.1.28 is unreachable
# 192.168.1.29 is unreachable
# 192.168.1.30 is reachable
# 192.168.1.31 is unreachable
# 192.168.1.32 is unreachable
# 192.168.1.33 is unreachable
# 192.168.1.34 is unreachable
# 192.168.1.35 is unreachable
# 192.168.1.36 is unreachable
# 192.168.1.37 is unreachable
# 192.168.1.38 is unreachable
# 192.168.1.39 is reachable
# 192.168.1.40 is unreachable
# 192.168.1.41 is reachable
# 192.168.1.42 is unreachable
# 192.168.1.43 is reachable
# 192.168.1.44 is unreachable
# 192.168.1.45 is reachable
# 192.168.1.46 is unreachable
# 192.168.1.47 is reachable
# 192.168.1.48 is reachable
# 192.168.1.49 is reachable
# 192.168.1.50 is reachable
# 192.168.1.51 is unreachable
# 192.168.1.52 is unreachable
# 192.168.1.53 is unreachable
# 192.168.1.54 is unreachable
# 192.168.1.55 is unreachable
# 192.168.1.56 is unreachable
# 192.168.1.57 is unreachable
# 192.168.1.58 is unreachable
# 192.168.1.59 is unreachable
# 192.168.1.60 is unreachable
# 192.168.1.61 is unreachable
# 192.168.1.62 is unreachable
# 192.168.1.63 is unreachable
# 192.168.1.64 is unreachable
# 192.168.1.65 is unreachable
# 192.168.1.66 is unreachable
# 192.168.1.67 is unreachable
# 192.168.1.68 is unreachable
# 192.168.1.69 is unreachable
# 192.168.1.70 is unreachable
# 192.168.1.71 is unreachable
# 192.168.1.72 is unreachable
# 192.168.1.73 is unreachable
# 192.168.1.74 is unreachable
# 192.168.1.75 is unreachable
# 192.168.1.76 is unreachable
# 192.168.1.77 is unreachable
# 192.168.1.78 is unreachable
# 192.168.1.79 is unreachable
# 192.168.1.80 is unreachable
# 192.168.1.81 is unreachable
# 192.168.1.82 is unreachable
# 192.168.1.83 is unreachable
# 192.168.1.84 is unreachable
# 192.168.1.85 is unreachable
# 192.168.1.86 is unreachable
# 192.168.1.87 is unreachable
# 192.168.1.88 is unreachable
# 192.168.1.89 is unreachable
# 192.168.1.90 is unreachable
# 192.168.1.91 is unreachable
# 192.168.1.92 is unreachable
# 192.168.1.93 is unreachable
# 192.168.1.94 is unreachable
# 192.168.1.95 is unreachable
# 192.168.1.96 is unreachable
# 192.168.1.97 is unreachable
# 192.168.1.98 is unreachable
# 192.168.1.99 is reachable
# 192.168.1.100 is reachable
# 192.168.1.101 is reachable
# 192.168.1.102 is reachable
# 192.168.1.103 is unreachable
# 192.168.1.104 is reachable
# 192.168.1.105 is unreachable
# 192.168.1.106 is reachable
# 192.168.1.107 is reachable
# 192.168.1.108 is reachable
# 192.168.1.109 is reachable
# 192.168.1.110 is reachable
# 192.168.1.111 is reachable
# 192.168.1.112 is reachable
# 192.168.1.113 is reachable
# 192.168.1.114 is reachable
# 192.168.1.115 is reachable
# 192.168.1.116 is reachable
# 192.168.1.117 is reachable
# 192.168.1.118 is reachable
# 192.168.1.119 is reachable
# 192.168.1.120 is reachable
# 192.168.1.121 is reachable
# 192.168.1.122 is reachable
# 192.168.1.123 is reachable
# 192.168.1.124 is reachable
# 192.168.1.125 is reachable
# 192.168.1.126 is unreachable
# 192.168.1.127 is reachable
# 192.168.1.128 is reachable
# 192.168.1.129 is reachable
# 192.168.1.130 is reachable
# 192.168.1.131 is reachable
# 192.168.1.132 is unreachable
# 192.168.1.133 is unreachable
# 192.168.1.134 is reachable
# 192.168.1.135 is unreachable
# 192.168.1.136 is unreachable
# 192.168.1.137 is unreachable
# 192.168.1.138 is unreachable
# 192.168.1.139 is unreachable
# 192.168.1.140 is reachable
# 192.168.1.141 is reachable
# 192.168.1.142 is reachable
# 192.168.1.143 is reachable
# 192.168.1.144 is reachable
# 192.168.1.145 is reachable
# 192.168.1.146 is unreachable
# 192.168.1.147 is unreachable
# 192.168.1.148 is reachable
# 192.168.1.149 is reachable
# 192.168.1.150 is reachable
# 192.168.1.151 is unreachable
# 192.168.1.152 is unreachable
# 192.168.1.153 is unreachable
# 192.168.1.154 is reachable
# 192.168.1.155 is reachable
# 192.168.1.156 is unreachable
# 192.168.1.157 is unreachable
# 192.168.1.158 is reachable
# 192.168.1.159 is reachable
# 192.168.1.160 is unreachable
# 192.168.1.161 is reachable
# 192.168.1.162 is reachable
# 192.168.1.163 is reachable
# 192.168.1.164 is unreachable
# 192.168.1.165 is unreachable
# 192.168.1.166 is unreachable
# 192.168.1.167 is unreachable
# 192.168.1.168 is reachable
# 192.168.1.169 is reachable
# 192.168.1.170 is unreachable
# 192.168.1.171 is reachable
# 192.168.1.172 is unreachable
# 192.168.1.173 is unreachable
# 192.168.1.174 is unreachable
# 192.168.1.175 is unreachable
# 192.168.1.176 is unreachable
# 192.168.1.177 is unreachable
# 192.168.1.178 is unreachable
# 192.168.1.179 is unreachable
# 192.168.1.180 is unreachable
# 192.168.1.181 is unreachable
# 192.168.1.182 is unreachable
# 192.168.1.183 is unreachable
# 192.168.1.184 is unreachable
# 192.168.1.185 is unreachable
# 192.168.1.186 is unreachable
# 192.168.1.187 is unreachable
# 192.168.1.188 is unreachable
# 192.168.1.189 is reachable
# 192.168.1.190 is unreachable
# 192.168.1.191 is unreachable
# 192.168.1.192 is unreachable
# 192.168.1.193 is unreachable
# 192.168.1.194 is unreachable
# 192.168.1.195 is reachable
# 192.168.1.196 is unreachable
# 192.168.1.197 is unreachable
# 192.168.1.198 is unreachable
# 192.168.1.199 is unreachable
# 192.168.1.200 is unreachable
# 192.168.1.201 is unreachable
# 192.168.1.202 is unreachable
# 192.168.1.203 is unreachable
# 192.168.1.204 is unreachable
# 192.168.1.205 is unreachable
# 192.168.1.206 is unreachable
# 192.168.1.207 is unreachable
# 192.168.1.208 is unreachable
# 192.168.1.209 is unreachable
# 192.168.1.210 is unreachable
# 192.168.1.211 is unreachable
# 192.168.1.212 is unreachable
# 192.168.1.213 is unreachable
# 192.168.1.214 is unreachable
# 192.168.1.215 is unreachable
# 192.168.1.216 is unreachable
# 192.168.1.217 is unreachable
# 192.168.1.218 is unreachable
# 192.168.1.219 is unreachable
# 192.168.1.220 is unreachable
# 192.168.1.221 is unreachable
# 192.168.1.222 is unreachable
# 192.168.1.223 is unreachable
# 192.168.1.224 is unreachable
# 192.168.1.225 is unreachable
# 192.168.1.226 is unreachable
# 192.168.1.227 is unreachable
# 192.168.1.228 is unreachable
# 192.168.1.229 is unreachable
# 192.168.1.230 is unreachable
# 192.168.1.231 is unreachable
# 192.168.1.232 is unreachable
# 192.168.1.233 is unreachable
# 192.168.1.234 is unreachable
# 192.168.1.235 is unreachable
# 192.168.1.236 is unreachable
# 192.168.1.237 is unreachable
# 192.168.1.238 is unreachable
# 192.168.1.239 is unreachable
# 192.168.1.240 is unreachable
# 192.168.1.241 is unreachable
# 192.168.1.242 is unreachable
# 192.168.1.243 is unreachable
# 192.168.1.244 is unreachable
# 192.168.1.245 is unreachable
# 192.168.1.246 is unreachable
# 192.168.1.247 is unreachable
# 192.168.1.248 is unreachable
# 192.168.1.249 is unreachable
# 192.168.1.250 is unreachable
# 192.168.1.251 is unreachable
# 192.168.1.252 is unreachable
# 192.168.1.253 is unreachable
# 192.168.1.254 is unreachable
